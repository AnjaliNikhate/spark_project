# %% [markdown]
# #**Author : Anjali Vijay Nikhate**
# #**Email : anjalinikhate@gmail.com**
# ##**Task 2 : Prediction using Unsupervised Machine Learning**
# #**GRIP @ The Sparks Foundation**
# #**Role : Data Science and Business Analytics [Batch september-2021]**

# %% [markdown]
# ##**Table of Contents**
#
#
# *   Introduction.
# *   Importing Libraries.
# *   Fetching and loading data.
# *   Checking for null values.
# *   Plotting Pairplot.
# *   Building K means clustering Model.
# *   Visualising the clusters with centroids.
# *   Conclusion.

# %% [markdown]
# #**Introduction**
#
#
# *   We are given the iris flower dataset, with featues sepal length, sepal width, petal length and petal width.
# *   Our aim is to create a K means clustering classifier to classify the flowers in categories that are: Iris setosa, Iris versicolor, and Iris virginica.
# *   Here, Python language is used to build the classifier.
# *   Dataset link: https://bit.ly/3kXTdox

# %%
from PIL import Image
img = Image.open('/content/sample_data/Iris.png')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=367x137 at 0x7FABED25A950>

# %% [markdown]
# #**Importing Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #**Fetching and loading data**

# %%
iris = pd.read_csv("/content/sample_data/Iris.csv")

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris = iris.drop(['Id'], axis = 1)
iris
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# In iris dataset, 5 features and 150 datapoints are present.

# %%
x = iris.iloc[:, : -1].values         # Assigning all the four features to variable x

# %% [markdown]
# #**Checking for Null values**

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# Here, we can see that no null values are present.

# %%
iris['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: Species, dtype: int64

# %% [markdown]
# From the above data we can say that, the iris dataset is a balanced dataset as the number of datapoints for every class are same.

# %% [markdown]
# #**Plotting Pairplot**

# %%
sns.set_style("whitegrid")
sns.pairplot(iris,hue="Species",size=1.75);
plt.show()

# %% [markdown]
# From the above pairplot, using Petal Length and Petal Width would be best the features to categorize datapoints.

# %% [markdown]
# #**K Means Clustering**
# ##**The Elbow Method**

# %%
#Finding the optimum number of clusters for k-means classification using Elbow Method
from sklearn.cluster import KMeans
wcss = []                                      ## WCSS (within cluster sum of squares) is the sum of squared distance between each point and the centroid in a cluster.

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)

# %%
#Plotting The Elbow graph
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %% [markdown]
# For the above-given graph, the optimum value for K would be 3. As we can see that with an increase in the number of clusters the WCSS value decreases. We select the value for K on the basis of the rate of decrease in WCSS. For example, from cluster 1 to 2 in the above graph we see a sudden and huge drop in WCSS. After 3 the drop is minimal and hence we chose 3 to be the optimal value for K.

# %% [markdown]
# ##**Silhouette Score**

# %%
for num_clusters in range(2,11):
    
    # intialise kmeans
    kmeans = KMeans(n_clusters=num_clusters, max_iter=50)
    kmeans.fit(x)
    
    cluster_labels = kmeans.labels_
    
    # silhouette score
    silhouette_avg = silhouette_score(x, cluster_labels)
    print("For n_clusters={0}, the silhouette score is {1}".format(num_clusters, silhouette_avg))
# Out:
# For n_clusters=2, the silhouette score is 0.6808136202936816
# For n_clusters=3, the silhouette score is 0.5525919445499757
# For n_clusters=4, the silhouette score is 0.4972279726640147
# For n_clusters=5, the silhouette score is 0.4885175508886279
# For n_clusters=6, the silhouette score is 0.36650401502359653
# For n_clusters=7, the silhouette score is 0.36220099717124493
# For n_clusters=8, the silhouette score is 0.35343479839826647
# For n_clusters=9, the silhouette score is 0.34477206613221334
# For n_clusters=10, the silhouette score is 0.3418678552479354

# %%
sns.set_style('whitegrid')
sns.FacetGrid(iris, hue = 'Species', size = 4).map(plt.scatter, 'PetalLengthCm', 'PetalWidthCm').add_legend()
plt.show()

# %%
# final model with k=3
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(x)

# %% [markdown]
# #**Visualising the Clusters with centroids**

# %%
#Visualising the clusters
fig = plt.figure(figsize= (6, 6))
plt.scatter(x[y_kmeans == 0, 2], x[y_kmeans == 0, 3], s = 100, c = 'purple', label = 'Iris-virginica')
plt.scatter(x[y_kmeans == 1, 2], x[y_kmeans == 1, 3], s = 100, c = 'orange', label = 'Iris-setosa')
plt.scatter(x[y_kmeans == 2, 2], x[y_kmeans == 2, 3], s = 100, c = 'green', label = 'Iris-versicolor')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 2], kmeans.cluster_centers_[:,3], s = 100, c = 'red', label = 'Centroids')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.legend();

# %% [markdown]
# #**Conclusion**
#
#
# *   Using Petal length and Petal width features, we can distinguish Setosa flowers from others.
# *   Seperating versicolor from virginica is quite hard as they have few datapoints considerably overlapped.
